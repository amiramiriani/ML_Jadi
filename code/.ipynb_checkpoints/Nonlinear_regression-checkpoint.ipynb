# %% [markdown]
# <h1>Table of contents</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href="#Quadratic">Quadratic</a></li>
#         <li><a href="#Exponential">Exponential</a></li>
#         <li><a href="#Logarithmic">Logarithmic</a></li>
#         <li><a href="#Sigmoidal/Logistic">Sigmoidal/Logistic</a></li>
#         <li><a href="#Data">Data</a></li>
#         <li><a href="#Selecting-And-Preprocessing">Selecting And Preprocessing</a></li>
#         <li><a href="#Model">Model</a></li>
#         <li><a href="#Evaluation">Evaluation</a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# # importing libs

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

# %% [markdown]
# ### Quadratic
# $$ Y = X^2 $$

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = np.power(x,2)

y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise

plt.plot(x, ydata,  'bo' , markersize=4)
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# ### Exponential
# $$ Y = a + b c^X $$

# %%
X_exp = np.arange(-5.0, 5.0, 0.1)
Y_exp = np.exp(X_exp)

noise = 0.3* np.random.normal(size=X_exp.size)
ydata = Y_exp * (1 + noise)

plt.plot(X_exp, Y_exp, label='exp(x)')
plt.plot(X_exp, ydata, 'ro', markersize=4)
plt.show()

# %% [markdown]
# ### Logarithmic
#
# The response $y$ is a results of applying the logarithmic map from the input $x$ to the output $y$. It is one of the simplest form of **log()**: i.e. $$ y = \log(x)$$
#
# Please consider that instead of $x$, we can use $X$, which can be a polynomial representation of the $x$ values. In general form it would be written as\
# \begin{equation}
# y = \log(X)
# \end{equation}

# %%
X_log = np.arange(0.1, 5.0, 0.1)
Y_log = np.log(X_log)

ydata_log = Y_log * (1 + 0.2 * np.random.normal(size=X_log.size))

plt.plot(X_log, Y_log, label='log(x)')
plt.plot(X_log, ydata_log, 'bo', markersize=4)
plt.show()

# %% [markdown]
# ### Sigmoidal/Logistic
# <div style= "text-align:center; font-size:20px; margin:25px 0;"> $$ Y = a + \frac{b}{1+ c^{(X-d)}}$$ </div>

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y = 1 - 4/(1 + np.power(3, X-2))

slope = np.gradient(Y)
noise = 4 * np.abs(slope) * np.random.normal(size=X.size)
ydata = Y + noise

plt.plot(X, Y)
plt.plot(X, ydata, 'ro', markersize=3)
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.show()

# %% [markdown]
# <h1 label = "#Data" >Data</h1>

# %%
df = pd.read_csv("../data/china_gdp.csv")
df.head()
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10

# %% [markdown]
# <h1 label = Selecting-And-Preprocessing >Selecting And Preprocessing</h1>

# %%
plt.figure(figsize=(10,6))
x_data, y_data = (df["Year"].values, df["Value"].values)
plt.plot(x_data, y_data, 'ro', markersize=6)
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### seperairng data (train and test)

# %%
df_norm = df.copy()

df_norm['Year'] = df_norm['Year'] / df_norm['Year'].max()
df_norm['Value'] = df_norm['Value'] / df_norm['Value'].max()

mask = np.random.rand(len(df_norm)) < 0.7
train = df_norm[mask]
test = df_norm[~mask]

xdata = train['Year']
ydata = train['Value']

x_test = test['Year']
y_test = test['Value']

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y = 1.0 / (1.0 + np.exp(-X))

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# <div style= "text-align:center; font-size:24px; margin:25px 0;">
#
# The formula for the logistic function is the following:
#
# $$ \hat{Y} = \frac1{1+e^{\beta\_1(X-\beta\_2)}}$$
#
# $\beta\_1$: Controls the curve's steepness,
#
# $\beta\_2$: Slides the curve on the x-axis.
# </div>

# %% [markdown]
# <h1 label = "Model">Model</h1>

# %%
def sigmoid(x, Beta_1, Beta_2):
     y = 1 / (1 + np.exp(-Beta_1*(x-Beta_2)))
     return y

# %%
beta_1 = 0.6
beta_2 = 2010.0

Y_pred = sigmoid(x_data, beta_1 , beta_2)

plt.plot(x_data, Y_pred*15000000000000.)
plt.plot(x_data, y_data, 'ro')

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(sigmoid, xdata, ydata)
#print the final parameters
print(" beta_1 = %f, beta_2 = %f" % (popt[0], popt[1]))
# Out:
#  beta_1 = 664.022400, beta_2 = 0.997243

# %%
x = np.linspace(1960, 2015, 55)
x = x/max(x)
plt.figure(figsize=(8,5))
y = sigmoid(x, *popt)
plt.plot(xdata, ydata, 'ro', label='data')
plt.plot(x,y, linewidth=3.0, label='fit')
plt.legend(loc='best')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# <h1 label = "Evaluation">Evaluation</h1>

# %%
y_test_ = sigmoid(x_test, *popt)

print('MAE : ',np.mean(np.absolute(y_test_-y_test)))
print('MSE : ',np.mean(np.square(y_test_-y_test)))
print('R_score : ',r2_score(y_test,y_test_))
# Out:
# MAE :  0.021890197912260396
# MSE :  0.0011453437154290268
# R_score :  0.9752046787329127
